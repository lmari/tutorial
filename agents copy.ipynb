# %%
import agents

agents.conversation = ""

starting_message="""**Introduzione**: Buongiorno cari colleghi. Dobbiamo scegliere un nome per il corso di introduzione all'intelligenza artificiale
    che stiamo finendo di progettare e che, vi ricordo, è rivolto a manager di organizzazioni che,
    senza voler diventare esperti di questioni tecniche, sono interessati a comprendere 
    potenzialità e rischi di questa tecnologia. Chiedo al creativo di proporre tre idee e di sottoporle all'analista,
    che farà le sue valutazioni e mi farà di conseguenza la sua proposta, concludendo così il nostro lavoro."""

creative = agents.Agent(name="Creativo", stream=True,
    system_message="""Sei il creativo dell'organizzazione: il tuo compito è di proporre molteplici idee innovative,
    che il tuo collega analista valuterà e da cui sceglierà quella che ritiene la migliore.
    Per chiarezza, presenta sempre le tue proposte in un elenco.""")

analyst = agents.Agent(name="Analista",
    system_message="""Sei l'analista dell'organizzazione: non devi fare proposte, ma attendere quelle del tuo collega creativo
    e valutarle attentamente, motivando la tua scelta. Il tuo compito è di scegliere quella che ritieni migliore,
    eventualmente modificarla per migliorarla, e motivare la tua scelta.""")


creative.request("Presentati: chi sei?")
analyst.request("Presentati: chi sei?")

agents.set_context(starting_message)
analyst.request()
creative.request()
analyst.request()
# Out:
# **Introduzione**: Buongiorno cari colleghi. Dobbiamo scegliere un nome per il corso di introduzione all'intelligenza artificiale
#     che stiamo finendo di progettare e che, vi ricordo, è rivolto a manager di organizzazioni che,
#     senza voler diventare esperti di questioni tecniche, sono interessati a comprendere
#     potenzialità e rischi di questa tecnologia. Chiedo al creativo di proporre tre idee e di sottoporle all'analista,
#     che farà le sue valutazioni e mi farà di conseguenza la sua proposta, concludendo così il nostro lavoro.
#
# <p style='text-align:center'>***</p>
#
# **Analista**: Buongiorno a tutti. Ottima iniziativa. Comprendo l'importanza di un nome efficace per questo corso, che deve catturare l'attenzione dei manager e comunicare chiaramente il suo valore.
#
# In attesa delle proposte del collega creativo, ho fatto una breve analisi preliminare considerando i seguenti aspetti:
#
# *   **Chiarezza:** Il nome deve essere immediatamente comprensibile ai destinatari (manager).
# *   **Rilevanza:** Deve riflettere l'argomento principale del corso (IA) e il suo orientamento pratico.
# *   **Appeal:** Deve essere interessante e invogliare all’iscrizione.
#
# Non avendo ancora le proposte, mi concentrerò sulla formulazione di un nome provvisorio che possa fungere da punto di partenza per la discussione, in attesa del contributo creativo: "**IA Strategica: Il Futuro dell'Impresa**".
#
# Questo titolo è volutamente ampio e ambizioso. "IA Strategica" sottolinea l'importanza dell’intelligenza artificiale come strumento decisionale e non solo come tecnologia da imparare. “Il Futuro dell’Impresa” pone il focus sul beneficio che i partecipanti otterranno, ovvero una visione orientata al futuro del loro business.
#
# Sono pronto ad analizzare le proposte del collega creativo e a fornire un feedback più dettagliato.
#
#
# <p style='text-align:center'>***</p>
#
# **Creativo**: Buongiorno a tutti! Ottimo lavoro di analisi da parte vostra. Ecco tre idee per il nome del corso, con l'obiettivo di essere chiari, rilevanti e accattivanti per i manager:
#
# 1.  **IA Manager: Potenzia il Tuo Business** – Questo titolo è diretto e usa un linguaggio che i manager comprend
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 27
#      25 agents.set_context(starting_message)
#      26 analyst.request()
# ---> 27 creative.request()
#      28 analyst.request()
#
# File ~/Bin/tutorial/agents.py:79, in Agent.request(self, message, last_message_only)
#      77             self.last_response = "**" + self.name + "**: " + self.last_response + sep # type: ignore
#      78 else:
# ---> 79     self.last_response = stream_print_markdown(self.name, response, conversation, printing=self.printing)
#      80 last_message = self.last_response
#      81 conversation += self.last_response
#
# File ~/Bin/tutorial/agents.py:26, in stream_print_markdown(name, response, conversation, printing)
#      24 buffer = "**" + name + "**: "
#      25 local_conversation = conversation + buffer
# ---> 26 for chunk in response:
#      27     text = chunk.choices[0].delta
#      28     if hasattr(text, 'content') and text.content:
#
# File ~/Bin/tutorial/.venv/lib/python3.13/site-packages/openai/_streaming.py:46, in Stream.__iter__(self)
#      45 def __iter__(self) -> Iterator[_T]:
# ---> 46     for item in self._iterator:
#      47         yield item
#
# File ~/Bin/tutorial/.venv/lib/python3.13/site-packages/openai/_streaming.py:58, in Stream.__stream__(self)
#      55 process_data = self._client._process_response_data
#      56 iterator = self._iter_events()
# ---> 58 for sse in iterator:
#      59     if sse.data.startswith("[DONE]"):
#      60         break
#
# File ~/Bin/tutorial/.venv/lib/python3.13/site-packages/openai/_streaming.py:50, in Stream._iter_events(self)
#      49 def _iter_events(self) -> Iterator[ServerSentEvent]:
# ---> 50     yield from self._decoder.iter_bytes(self.response.iter_bytes())
#
# File ~/Bin/tutorial/.venv/lib/python3.13/site-packages/openai/_streaming.py:280, in SSEDecoder.iter_bytes(self, iterator)
#     278 def iter_bytes(self, iterator: Iterator[bytes]) -> Iterator[ServerSentEvent]:
#     279     """Given an iterator that yields raw binary data, iterate over it & yield every event encountered"""
# --> 280     for chunk in self._iter_chunks(iterator):
#     281         # Split before decoding so splitlines() only uses \r and \n
#     282         for raw_line in chunk.splitlines():
#     283             line = raw_line.decode("utf-8")
#
# File ~/Bin/tutorial/.venv/lib/python3.13/site-packages/openai/_streaming.py:291, in SSEDecoder._iter_chunks(self, iterator)
#     289 """Given an iterator that yields raw binary data, iterate over it and yield individual SSE chunks"""
#     290 data = b""
# --> 291 for chunk in iterator:
#     292     for line in chunk.splitlines(keepends=True):
#     293         data += line
#
# File ~/Bin/tutorial/.venv/lib/python3.13/site-packages/httpx/_models.py:897, in Response.iter_bytes(self, chunk_size)
#     895 chunker = ByteChunker(chunk_size=chunk_size)
#     896 with request_context(request=self._request):
# --> 897     for raw_bytes in self.iter_raw():
#     898         decoded = decoder.decode(raw_bytes)
#     899         for chunk in chunker.decode(decoded):
#
# File ~/Bin/tutorial/.venv/lib/python3.13/site-packages/httpx/_models.py:951, in Response.iter_raw(self, chunk_size)
#     948 chunker = ByteChunker(chunk_size=chunk_size)
#     950 with request_context(request=self._request):
# --> 951     for raw_stream_bytes in self.stream:
#     952         self._num_bytes_downloaded += len(raw_stream_bytes)
#     953         for chunk in chunker.decode(raw_stream_bytes):
#
# File ~/Bin/tutorial/.venv/lib/python3.13/site-packages/httpx/_client.py:153, in BoundSyncStream.__iter__(self)
#     152 def __iter__(self) -> typing.Iterator[bytes]:
# --> 153     for chunk in self._stream:
#     154         yield chunk
#
# File ~/Bin/tutorial/.venv/lib/python3.13/site-packages/httpx/_transports/default.py:127, in ResponseStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
#     126     with map_httpcore_exceptions():
# --> 127         for part in self._httpcore_stream:
#     128             yield part
#
# File ~/Bin/tutorial/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:407, in PoolByteStream.__iter__(self)
#     405 except BaseException as exc:
#     406     self.close()
# --> 407     raise exc from None
#
# File ~/Bin/tutorial/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:403, in PoolByteStream.__iter__(self)
#     401 def __iter__(self) -> typing.Iterator[bytes]:
#     402     try:
# --> 403         for part in self._stream:
#     404             yield part
#     405     except BaseException as exc:
#
# File ~/Bin/tutorial/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     340 with ShieldCancellation():
#     341     self.close()
# --> 342 raise exc
#
# File ~/Bin/tutorial/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     332 try:
#     333     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334         for chunk in self._connection._receive_response_body(**kwargs):
#     335             yield chunk
#     336 except BaseException as exc:
#     337     # If we get an exception while streaming the response,
#     338     # we want to close the response (and possibly the connection)
#     339     # before raising that exception.
#
# File ~/Bin/tutorial/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     200 timeout = timeouts.get("read", None)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#     205         yield bytes(event.data)
#
# File ~/Bin/tutorial/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Bin/tutorial/.venv/lib/python3.13/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %%
agents.last_message
# Out:
# '**Analista**: **Analista**: Buongiorno. Dopo aver valutato le proposte, ritengo che "AI & Business: La Rivoluzione a Portata di Manager" sia la scelta migliore.\n\n**Motivazione:** Pur riconoscendo i punti validi delle altre proposte, questo nome cattura al meglio l’entusiasmo e l’impatto potenziale dell\'IA per il target manageriale. L\'uso della parola "Rivoluzione" crea un senso di novità e opportunità, mentre “a Portata di Manager” rassicura sull’accessibilità del corso e sul focus sulle esigenze specifiche dei partecipanti. La sua lunghezza e la combinazione di elementi sono particolarmente efficaci per attirare l’attenzione.\n\n\n<p style=\'text-align:center\'>***</p>\n\n'
